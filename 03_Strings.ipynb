# %% [markdown]
# <a href="https://colab.research.google.com/github/SonyZaman/Python/blob/main/03_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %% [markdown]
# ## Creating Stings

# %%
s = 'hello'
s = "hello"
# multiline strings
s = '''hello'''
s = """hello"""
s = str('hello')
print(s)
# Out:
# hello

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %% [markdown]
# ## Accessing Substrings from a String

# %%
# Positive Indexing
s = 'hello world'
print(s[1])
# Out:
# e

# %%
# Negative Indexing
s = 'hello world'
print(s[-3])
# Out:
# r

# %%
# Slicing
s = 'abcdefghijklm'
print(s[1:7:2])
# Out:
# bdf

# %%
s = 'abcdefghijklm'
print(s[6:1:-2])
# Out:
# gec

# %%
print(s[::-1])
# Out:
# mlkjihgfedcba

# %%
s = 'hello world'
print(s[-1:-6:-1])
# Out:
# dlrow

# %% [markdown]
# ## Editing in Strings

# %%
s = 'hello world'
s[0] = 'H'

# Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7422/2237226474.py in <cell line: 0>()
#       1 s = 'hello world'
# ----> 2 s[0] = 'H'
#       3
#       4 # Python strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Deleting in Strings

# %%
s = 'hello world'
del s
#print(s)

# %%
s = 'hello world'
del s[-1:-5:2]
print(s) # not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4703/3325277908.py in <cell line: 0>()
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s) # not possible
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# ## Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %% [markdown]
# Arithmetic Operator

# %%
print('Dhaka' + ' ' + 'Chattogram')
# Out:
# Dhaka Chattogram

# %%
print('Dhaka'*5)
# Out:
# DhakaDhakaDhakaDhakaDhaka

# %%
print("*"*50)
# Out:
# **************************************************

# %% [markdown]
# Relational Operator

# %%
'Dhaka' == 'Dhaka'
# Out:
# True

# %%
'Dhaka' > 'Rajshahi'
# lexiographically
# Out:
# False

# %%
'Dhaka' > 'dhaka'
# Out:
# False

# %% [markdown]
# Logical Operator

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
not 'hello'
# Out:
# False

# %% [markdown]
# Loops on Strings

# %%
for i in 'hello':
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
for i in 'Dhaka':
  print('Chattogram')
# Out:
# Chattogram
# Chattogram
# Chattogram
# Chattogram
# Chattogram

# %% [markdown]
# Membership Operator

# %%
'D' in 'dhaka'
# Out:
# False

# %% [markdown]
# ## Common Functions
# - len
# - max
# - min
# - sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world',reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# ## Capitalize/Title/Upper/Lower/Swapcase

# %%
# original string remains unchanged

s = 'hello world'
print(s.capitalize())
print(s)
# Out:
# Hello world
# hello world

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
'Hello Wolrd'.lower()
# Out:
# 'hello wolrd'

# %%
'HeLlO WorLD'.swapcase()
# Out:
# 'hElLo wORld'

# %% [markdown]
# ## Count/Find/Index

# %%
'my name is sonyso'.count('so')
# Out:
# 2

# %%
print('my name is sonyso'.find('so'))
# Out:
# 11

# %%
print('my name is sonyso'.find('x'))
# Out:
# -1

# %%
'my name is sonyso'.index('so')
# Out:
# 11

# %%
'my name is sonyso'.index('so')
# Out:
# 11

# %% [markdown]
# ## endswith/startswith

# %%
'my name is sonyso'.endswith('aka')
# Out:
# False

# %%
'my name is sonyso'.startswith('my n')
# Out:
# True

# %% [markdown]
# ## format

# %%
name = 'Sony'
gender = 'male'

'Hi my name is {0} and I am a {1}'.format(name,gender)
# Out:
# 'Hi my name is Sony and I am a male'

# %% [markdown]
# ## isalnum/ isalpha/ isdigit/ isidentifier

# %%
# Checks if all characters in the string are alphanumeric (letters or numbers)
'sonyso'.isalnum()
# Out:
# True

# %%
# Checks if all characters in the string are alphabetic (letters)
'nitish'.isalpha()
# Out:
# True

# %%
# Checks if all characters in the string are digits
'123abc'.isdigit()
# Out:
# False

# %%
# Checks if the string is a valid identifier (e.g., for variable names)
'first-name'.isidentifier()
# Out:
# False

# %% [markdown]
# ## Split/Join

# %%
# Splits the string into a list of substrings based on whitespace
"hi my name is Sony".split()
# Out:
# ['hi', 'my', 'name', 'is', 'Sony']

# %%
# Joins the elements of an iterable (list) into a single string using the specified separator
# "separator".join(iterable_of_strings)
"-".join(['My', 'name', 'is', 'Sony'])
# Out:
# 'My-name-is-Sony'

# %% [markdown]
# ## Replace

# %%
# Replaces all occurrences of a specified substring with another substring
'hi my name is Sony'.replace('Sony','Zaman')
# Out:
# 'hi my name is Zaman'

# %% [markdown]
# ## Strip

# %%
# Removes leading and trailing whitespace (or specified characters) from the string
'so ny                          '.strip()
# Out:
# 'so ny'

# %% [markdown]
# ## Example Programs

# %%
# Find the length of a given string without using the len() function

s = input('Enter a string: ')

counter = 0

for i in s:
  counter += 1

print('Length of string is',counter)
# Out:
# Enter a string: Hi my
# Length of string is 5

# %%
# Extract username from a given email.
# Eg if the email is sony@gmail.com
# then the username should be sony

s = input('Enter your email: ')

pos = s.index('@')
print(s[0:pos])
# Out:
# Enter your email: sonyzaman9112@gmail.com
# sonyzaman9112

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('Enter the string: ')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')
# Out:
# Enter the string: madam
# Palindrome

# %%
# Convert into list from a string without split()

s = input('Enter the string: ')
L = []
temp = ''
for i in s:

  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
# Out:
# Enter the string: Hi, My name is sony
# ['Hi,', 'My', 'name', 'is', 'sony']

# %%
# Write a python program to convert a string to title case without using the title()
s = input('Enter the string: ')

L = []

for i in s.split():
  L.append(i[0].upper()+i[1:].lower())

' '.join(L)
# Out:
# Enter the string: Hi, my name is Sony
# 'Hi, My Name Is Sony'

# %%
# Write a program that can convert an integer to string.

number = int(input('Enter the number: '))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# Enter the number: 4738
# 4738
# <class 'str'>
