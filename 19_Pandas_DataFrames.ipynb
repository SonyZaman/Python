# %% [markdown]
# <a href="https://colab.research.google.com/github/SonyZaman/Python/blob/main/19_Pandas_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Table of Contents
#
# 1.  [Introduction](#introduction)
# 2.  [Importing Libraries](#importing-libraries)
# 3.  [Creating DataFrames](#creating-dataframes)
#     *   [From Lists](#from-lists)
#     *   [From Dictionaries](#from-dictionaries)
#     *   [From CSV Files](#from-csv-files)
# 4.  [DataFrame Attributes](#dataframe-attributes)
#     *   [`shape`](#shape)
#     *   [`dtypes`](#dtypes)
#     *   [`index`](#index)
#     *   [`columns`](#columns)
#     *   [`values`](#values)
# 5.  [DataFrame Inspection Methods](#dataframe-inspection-methods)
#     *   [`head()`](#head)
#     *   [`tail()`](#tail)
#     *   [`sample()`](#sample)
#     *   [`info()`](#info)
#     *   [`describe()`](#describe)
#     *   [`isnull()`](#isnull)
#     *   [`duplicated()`](#duplicated)
# 6.  [Data Manipulation](#data-manipulation)
#     *   [`rename()`](#rename)
#     *   [`set_index()`](#set_index)
# 7. [Math Methods](#math-methods)
#     *   [`sum()`](#sum)
#     *   [`mean()`](#mean)
#     *   [`median()`](#median)
#     *   [`var()`](#var)
#     *   [`std()`](#std)
#     *   [`max()`](#max)
#     *   [`min()`](#min)
#
# 8.  [Data Selection](#data-selection)
#     *   [Selecting Columns](#selecting-columns)
#     *   [Selecting Rows (iloc)](#selecting-rows-iloc)
#     *   [Selecting Rows (loc)](#selecting-rows-loc)
#     *   [Selecting Rows and Columns](#selecting-rows-and-columns)
# 9.  [Data Filtering](#data-filtering)
#     *   [Boolean Filtering](#boolean-filtering)
#     *   [`str.contains()`](#strcontains)
#     *   [`str.split().apply()`](#strsplitapply)
# 10.  [Adding New Columns](#adding-new-columns)
# 11. [Important DataFrame Functions](#important-dataframe-functions)
#     *   [`astype()`](#astype)
#     *   [`value_counts()`](#value-counts)
#     *   [`pd.concat()`](#pdconcat)
#     *   [`sort_values()`](#sort-values)

# %% [markdown]
# ### 2. Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 3. Creating DataFrames

# %%
# using lists
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dicts

student_dict = {
    'name':['Sony','Labib','Hasan','Rahman','Zaman','Karim'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_dict)
students.set_index('name',inplace=True)
students
# Out:
#          iq  marks  package
# name
# Sony    100     80       10
# Labib    90     70        7
# Hasan   120    100       14
# Rahman   80     50        2
# Zaman     0      0        0
# Karim     0      0        0

# %%
# using read_csv
movies = pd.read_csv('movies.csv')
movies
# Out:
#                 title_x     imdb_id  \
# 0             Gladiator   tt8291224
# 1             Inception   tt9472208
# 2             Inception   tt6986710
# 3               Titanic   tt8108208
# 4          Forrest Gump   tt6028796
# ...                 ...         ...
# 1624  Avengers: Endgame   tt0301250
# 1625            Titanic   tt0298607
# 1626         Fight Club   tt0069204
# 1627        Oppenheimer  tt10833860
# 1628            Titanic   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...                                                 ...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
cricket = pd.read_csv('cricket_matches.csv')
cricket
# Out:
#           ID        City        Date   Season MatchNumber        Team1  \
# 0    1304113   Melbourne  2022-05-19     2022          67     Pakistan
# 1    1304107   Melbourne  2022-05-14     2022          61   Bangladesh
# 2    1304090      Mumbai  2022-04-30     2022          44  West Indies
# 3    1304078  Manchester  2022-04-20     2022          32     Pakistan
# 4    1304075   Ahmedabad  2022-04-17     2022          29  New Zealand
# ..       ...         ...         ...      ...         ...          ...
# 113   336031     Kolkata  2008-05-23  2007/08          48      England
# 114   336024      Sydney  2008-05-18  2007/08          42    Australia
# 115   336009     Kolkata  2008-05-08  2007/08          28  New Zealand
# 116   336007    Adelaide  2008-05-06  2007/08          26    Australia
# 117   336034     Kolkata  2008-05-03  2007/08          21  New Zealand
#
#             Team2                           Venue   TossWinner TossDecision  \
# ...

# %% [markdown]
# ### 4. DataFrame Attributes

# %%
# shape
print(movies.shape)
print(cricket.shape)
# Out:
# (1629, 18)
# (118, 20)

# %%
# dtypes
cricket.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
print(movies.index)
print(cricket.index)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=118, step=1)

# %%
# columns
print(movies.columns,end='\n\n')
print(cricket.columns,end='\n\n')
print(students.columns,end='\n\n')
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')
#
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
#
# Index(['iq', 'marks', 'package'], dtype='object')

# %%
# values (DataFrame to 2D NumPy a)
cricket.values
# Out:
# array([[1304113, 'Melbourne', '2022-05-19', ...,
#         'Kane Williamson, Trent Boult, Devon Conway',
#         'Richard Kettleborough', 'Chris Gaffaney'],
#        [1304107, 'Melbourne', '2022-05-14', ...,
#         'Shakib Al Hasan, Tamim Iqbal, Mustafizur Rahman', 'Aleem Dar',
#         'Paul Reiffel'],
#        [1304090, 'Mumbai', '2022-04-30', ...,
#         'Nicholas Pooran, Jason Holder, Shimron Hetmyer', 'Rod Tucker',
#         'Nitin Menon'],
#        ...,
#        [336009, 'Kolkata', '2008-05-08', ...,
#         'Shakib Al Hasan, Tamim Iqbal, Mustafizur Rahman', 'Nitin Menon',
#         'Richard Kettleborough'],
#        [336007, 'Adelaide', '2008-05-06', ...,
#         'Babar Azam, Shaheen Afridi, Mohammad Rizwan',
#         'Richard Kettleborough', 'Paul Reiffel'],
#        [336034, 'Kolkata', '2008-05-03', ...,
#         'Shakib Al Hasan, Tamim Iqbal, Mustafizur Rahman',
#         'Paul Reiffel', 'Richard Kettleborough']], dtype=object)

# %% [markdown]
# ###6. DataFrame Inspection Methods

# %%
# head(first n values)
cricket.head(5)
# Out:
#         ID        City        Date Season MatchNumber        Team1  \
# 0  1304113   Melbourne  2022-05-19   2022          67     Pakistan
# 1  1304107   Melbourne  2022-05-14   2022          61   Bangladesh
# 2  1304090      Mumbai  2022-04-30   2022          44  West Indies
# 3  1304078  Manchester  2022-04-20   2022          32     Pakistan
# 4  1304075   Ahmedabad  2022-04-17   2022          29  New Zealand
#
#          Team2                           Venue   TossWinner TossDecision  \
# 0  West Indies                    Eden Gardens     Pakistan          bat
# 1     Pakistan  Sher-e-Bangla National Stadium   Bangladesh          bat
# 2     Pakistan           Narendra Modi Stadium  West Indies        field
# 3    Sri Lanka                Wankhede Stadium     Pakistan        field
# 4    Sri Lanka        Melbourne Cricket Ground    Sri Lanka        field
#
#   SuperOver  WinningTeam    WonBy  Margin method  Player_of_Match  \
# ...

# %%
# tail(last n values)
cricket.tail(5)
# Out:
#          ID      City        Date   Season MatchNumber        Team1  \
# 113  336031   Kolkata  2008-05-23  2007/08          48      England
# 114  336024    Sydney  2008-05-18  2007/08          42    Australia
# 115  336009   Kolkata  2008-05-08  2007/08          28  New Zealand
# 116  336007  Adelaide  2008-05-06  2007/08          26    Australia
# 117  336034   Kolkata  2008-05-03  2007/08          21  New Zealand
#
#             Team2                        Venue  TossWinner TossDecision  \
# 113   New Zealand                Adelaide Oval     England        field
# 114  South Africa                Adelaide Oval   Australia        field
# 115    Bangladesh  Old Trafford Cricket Ground  Bangladesh        field
# 116      Pakistan                 Eden Gardens   Australia        field
# 117    Bangladesh                 Eden Gardens  Bangladesh        field
#
#     SuperOver  WinningTeam    WonBy  Margin method    Player_of_Match  \
# ...

# %%
# sample(random n values)
cricket.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber         Team1  \
# 2    1304090     Mumbai  2022-04-30     2022          44   West Indies
# 103   392236  Melbourne  2009-05-21     2009          56  South Africa
# 1    1304107  Melbourne  2022-05-14     2022          61    Bangladesh
# 24   1216507  Ahmedabad  2020-10-11  2020/21          26      Pakistan
# 40   1082645     Mumbai  2017-05-14     2017          55         India
#
#           Team2                           Venue   TossWinner TossDecision  \
# 2      Pakistan           Narendra Modi Stadium  West Indies        field
# 103  Bangladesh                    Eden Gardens   Bangladesh          bat
# 1      Pakistan  Sher-e-Bangla National Stadium   Bangladesh          bat
# 24        India                    Eden Gardens        India          bat
# 40    Sri Lanka  Sher-e-Bangla National Stadium        India        field
#
#     SuperOver  WinningTeam    WonBy  Margin method  Player_of_Match  \
# ...

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1629 non-null   object
# ...

# %%
# info (Non-Null count,Dtype)
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               118 non-null    int64
#  1   City             118 non-null    object
#  2   Date             118 non-null    object
#  3   Season           118 non-null    object
#  4   MatchNumber      118 non-null    object
#  5   Team1            118 non-null    object
#  6   Team2            118 non-null    object
#  7   Venue            118 non-null    object
#  8   TossWinner       118 non-null    object
#  9   TossDecision     118 non-null    object
#  10  SuperOver        117 non-null    object
#  11  WinningTeam      118 non-null    object
#  12  WonBy            118 non-null    object
#  13  Margin           116 non-null    float64
#  14  method           3 non-null      object
#  15  Player_of_Match  118 non-null    object
# ...

# %%
# describe (statistics)
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
cricket.describe()
# Out:
#                  ID      Margin
# count  1.180000e+02  116.000000
# mean   8.296074e+05   19.491379
# std    3.444116e+05   26.069971
# min    3.360070e+05    2.000000
# 25%    5.012538e+05    6.000000
# 50%    8.297920e+05    8.000000
# 75%    1.175370e+06   22.000000
# max    1.304113e+06  138.000000

# %%
# isnull
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 0
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicate
print(students)
students.duplicated()
# Out:
#          iq  marks  package
# name
# Sony    100     80       10
# Labib    90     70        7
# Hasan   120    100       14
# Rahman   80     50        2
# Zaman     0      0        0
# Karim     0      0        0
# name
# Sony      False
# Labib     False
# Hasan     False
# Rahman    False
# Zaman     False
# Karim      True
# dtype: bool

# %%
students.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ###6. Data Manipulation

# %%
# rename
students
# Out:
#          iq  marks  package
# name
# Sony    100     80       10
# Labib    90     70        7
# Hasan   120    100       14
# Rahman   80     50        2
# Zaman     0      0        0
# Karim     0      0        0

# %%
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True)

# %%
students
# Out:
#          iq  percent  lpa
# name
# Sony    100       80   10
# Labib    90       70    7
# Hasan   120      100   14
# Rahman   80       50    2
# Zaman     0        0    0
# Karim     0        0    0

# %% [markdown]
# ### 7. Math Methods

# %%
students
# Out:
#          iq  percent  lpa
# name
# Sony    100       80   10
# Labib    90       70    7
# Hasan   120      100   14
# Rahman   80       50    2
# Zaman     0        0    0
# Karim     0        0    0

# %%
# sum(by default column wise)
students.sum()
# Out:
# iq         390
# percent    300
# lpa         33
# dtype: int64

# %%
# column wise
students.sum(axis=0)
# Out:
# iq         390
# percent    300
# lpa         33
# dtype: int64

# %%
# row wise
students.sum(axis=1)
# Out:
# name
# Sony      190
# Labib     167
# Hasan     234
# Rahman    132
# Zaman       0
# Karim       0
# dtype: int64

# %%
# col wise
students.mean(axis=0)
# Out:
# iq         65.0
# percent    50.0
# lpa         5.5
# dtype: float64

# %%
# row wise
students.mean(axis=1)
# Out:
# name
# Sony      63.333333
# Labib     55.666667
# Hasan     78.000000
# Rahman    44.000000
# Zaman      0.000000
# Karim      0.000000
# dtype: float64

# %%
students.median()
# Out:
# iq         85.0
# percent    60.0
# lpa         4.5
# dtype: float64

# %%
students.var()
# Out:
# iq         2710.0
# percent    1760.0
# lpa          33.5
# dtype: float64

# %%
students.std()
# Out:
# iq         52.057660
# percent    41.952354
# lpa         5.787918
# dtype: float64

# %%
students.max()
# Out:
# iq         120
# percent    100
# lpa         14
# dtype: int64

# %%
students.min()
# Out:
# iq         0
# percent    0
# lpa        0
# dtype: int64

# %% [markdown]
# ### 8.1 Selecting Columns

# %%
# single cols
movies['title_x']
# Out:
# 0               Gladiator
# 1               Inception
# 2               Inception
# 3                 Titanic
# 4            Forrest Gump
#               ...
# 1624    Avengers: Endgame
# 1625              Titanic
# 1626           Fight Club
# 1627          Oppenheimer
# 1628              Titanic
# Name: title_x, Length: 1629, dtype: object

# %%
cricket['Venue']
# Out:
# 0                        Eden Gardens
# 1      Sher-e-Bangla National Stadium
# 2               Narendra Modi Stadium
# 3                    Wankhede Stadium
# 4            Melbourne Cricket Ground
#                     ...
# 113                     Adelaide Oval
# 114                     Adelaide Oval
# 115       Old Trafford Cricket Ground
# 116                      Eden Gardens
# 117                      Eden Gardens
# Name: Venue, Length: 118, dtype: object

# %%
type(cricket['Venue'])
# Out:
# pandas.core.series.Series

# %%
# multiple cols
movies[['year_of_release','actors','title_x']]
# Out:
#       year_of_release             actors            title_x
# 0                2019      Russell Crowe          Gladiator
# 1                2019  Leonardo DiCaprio          Inception
# 2                2019  Leonardo DiCaprio          Inception
# 3                2019       Kate Winslet            Titanic
# 4                2018          Tom Hanks       Forrest Gump
# ...               ...                ...                ...
# 1624             2001  Robert Downey Jr.  Avengers: Endgame
# 1625             2001       Kate Winslet            Titanic
# 1626             2018          Brad Pitt         Fight Club
# 1627             2019     Cillian Murphy        Oppenheimer
# 1628             2011       Kate Winslet            Titanic
#
# [1629 rows x 3 columns]

# %%
cricket[['Team1','Team2','WinningTeam']]
# Out:
#            Team1         Team2  WinningTeam
# 0       Pakistan   West Indies     Pakistan
# 1     Bangladesh      Pakistan   Bangladesh
# 2    West Indies      Pakistan  West Indies
# 3       Pakistan     Sri Lanka     Pakistan
# 4    New Zealand     Sri Lanka    Sri Lanka
# ..           ...           ...          ...
# 113      England   New Zealand  New Zealand
# 114    Australia  South Africa    Australia
# 115  New Zealand    Bangladesh  New Zealand
# 116    Australia      Pakistan    Australia
# 117  New Zealand    Bangladesh   Bangladesh
#
# [118 rows x 3 columns]

# %%
type(cricket[['Team1','Team2','WinningTeam']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 8.2 Selecting Rows

# %%
# single row
students.iloc[1]
# Out:
# iq         90
# percent    70
# lpa         7
# Name: Labib, dtype: int64

# %%
type(students.iloc[1])
# Out:
# pandas.core.series.Series

# %%
# multiple row
students.iloc[:4]
# Out:
#          iq  percent  lpa
# name
# Sony    100       80   10
# Labib    90       70    7
# Hasan   120      100   14
# Rahman   80       50    2

# %%
type(students.iloc[:4])
# Out:
# pandas.core.frame.DataFrame

# %%
students.iloc[:5:2]
# Out:
#         iq  percent  lpa
# name
# Sony   100       80   10
# Hasan  120      100   14
# Zaman    0        0    0

# %%
# fancy indexing
students.iloc[[0,2,4,5]]
# Out:
#         iq  percent  lpa
# name
# Sony   100       80   10
# Hasan  120      100   14
# Zaman    0        0    0
# Karim    0        0    0

# %%
# loc
students
# Out:
#          iq  percent  lpa
# name
# Sony    100       80   10
# Labib    90       70    7
# Hasan   120      100   14
# Rahman   80       50    2
# Zaman     0        0    0
# Karim     0        0    0

# %%
students.loc['Sony']
# Out:
# iq         100
# percent     80
# lpa         10
# Name: Sony, dtype: int64

# %%
students.loc['Labib':'Karim':2]
# Out:
#         iq  percent  lpa
# name
# Labib   90       70    7
# Rahman  80       50    2
# Karim    0        0    0

# %%
students.loc[['Sony','Hasan','Zaman']]
# Out:
#         iq  percent  lpa
# name
# Sony   100       80   10
# Hasan  120      100   14
# Zaman    0        0    0

# %%
students.iloc[[0,3,4]]
# Out:
#          iq  percent  lpa
# name
# Sony    100       80   10
# Rahman   80       50    2
# Zaman     0        0    0

# %% [markdown]
# ### 8.3 Selecting Rows and Columns

# %%
students.iloc[1:3,1:3]
# Out:
#        percent  lpa
# name
# Labib       70    7
# Hasan      100   14

# %%
students.loc['Hasan':'Zaman',:'percent']
# Out:
#          iq  percent
# name
# Hasan   120      100
# Rahman   80       50
# Zaman     0        0

# %% [markdown]
# ### 9. Data Filtering

# %%
cricket.head(2)
# Out:
#         ID       City        Date Season MatchNumber       Team1        Team2  \
# 0  1304113  Melbourne  2022-05-19   2022          67    Pakistan  West Indies
# 1  1304107  Melbourne  2022-05-14   2022          61  Bangladesh     Pakistan
#
#                             Venue  TossWinner TossDecision SuperOver  \
# 0                    Eden Gardens    Pakistan          bat         N
# 1  Sher-e-Bangla National Stadium  Bangladesh          bat         N
#
#   WinningTeam    WonBy  Margin method  Player_of_Match  \
# 0    Pakistan  Wickets     8.0    NaN  Mohammad Rizwan
# 1  Bangladesh     Runs    54.0    NaN  Shakib Al Hasan
#
#                                   Team1Players  \
# 0  Babar Azam, Shaheen Afridi, Mohammad Rizwan
# 1  Babar Azam, Shaheen Afridi, Mohammad Rizwan
#
#                                       Team2Players                Umpire1  \
# 0       Kane Williamson, Trent Boult, Devon Conway  Richard Kettleborough
# ...

# %%
# find all the final winners
mask = cricket['MatchNumber'] == 'Final'
new_df = cricket[mask]
new_df[['Season','WinningTeam']]
# Out:
# Empty DataFrame
# Columns: [Season, WinningTeam]
# Index: []

# %%
# in one line
cricket[cricket['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
# Empty DataFrame
# Columns: [Season, WinningTeam]
# Index: []

# %%
# how many super over finishes have occured
cricket[cricket['SuperOver'] == 'Y'].shape[0]
# Out:
# 1

# %%
# how many matches has Australia won in Sydney
cricket[(cricket['City'] == 'Sydney') & (cricket['WinningTeam'] == 'Australia')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
(cricket[cricket['TossWinner'] == cricket['WinningTeam']].shape[0]/cricket.shape[0])*100
# Out:
# 88.98305084745762

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8.0) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5
# mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask1 = movies['genres'].str.contains('Action')
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2]
# Out:
#                 title_x    imdb_id  \
# 0             Gladiator  tt8291224
# 41    Avengers: Endgame  tt8897986
# 84         Forrest Gump  tt7180544
# 106          Fight Club  tt7098658
# 110           Inception  tt6826438
# 112         Oppenheimer  tt6129302
# 169   Avengers: Endgame  tt6299040
# 219     The Dark Knight  tt6080746
# 258           Inception  tt5310090
# 280           Gladiator  tt5600714
# 297            Deadpool  tt4434004
# 354   Avengers: Endgame  tt5074352
# 362           John Wick  tt3863552
# 365          Fight Club  tt3848892
# 393     The Dark Knight  tt3447364
# 449           John Wick  tt3019620
# 536              Avatar  tt3390572
# 589   Avengers: Endgame  tt2199711
# 625            Deadpool  tt2855648
# 668   Avengers: Endgame  tt1620933
# 693           John Wick  tt1954470
# 694             Titanic  tt1954470
# 982               Joker  tt0449994
# 1039       Forrest Gump  tt0983990
# 1058    The Dark Knight  tt0400234
# ...

# %%
# write a function that can return the track record of 2 teams against each other
cricket[((cricket['Team1']=='Australia') & (cricket['Team2']=='England') )|((cricket['Team1']=='England') & (cricket['Team2']=='Australia') )]['Team1']
# Out:
# 25    Australia
# 54    Australia
# 57    Australia
# 97    Australia
# Name: Team1, dtype: object

# %% [markdown]
# ### 10. Adding New Columns

# %%
# add new column Certified
movies['Certified'] = True
movies.head()
# Out:
#         title_x    imdb_id                                        poster_path  \
# 0     Gladiator  tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# 1     Inception  tt9472208                                                NaN
# 2     Inception  tt6986710  https://upload.wikimedia.org/wikipedia/en/thum...
# 3       Titanic  tt8108208  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  Forrest Gump  tt6028796                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
# Add a new column named 'prize_count', where the values are extracted from 'wins_nominations'
# Apply dropna() before string operations to handle NaN values, then extract the first part
# Rows with NaN in 'wins_nominations' will result in NaN in 'prize_count'
m_temp = movies['wins_nominations'].dropna()
movies['prize_count'] = m_temp.str.split(' ').apply(lambda x: x[0])

movies.head()
# Out:
#         title_x    imdb_id                                        poster_path  \
# 0     Gladiator  tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# 1     Inception  tt9472208                                                NaN
# 2     Inception  tt6986710  https://upload.wikimedia.org/wikipedia/en/thum...
# 3       Titanic  tt8108208  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  Forrest Gump  tt6028796                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1629 non-null   object
# ...

# %% [markdown]
# ### 11. Important DataFrame Functions

# %%
# astype() is used to change the data type of a given column
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               118 non-null    int64
#  1   City             118 non-null    object
#  2   Date             118 non-null    object
#  3   Season           118 non-null    object
#  4   MatchNumber      118 non-null    object
#  5   Team1            118 non-null    object
#  6   Team2            118 non-null    object
#  7   Venue            118 non-null    object
#  8   TossWinner       118 non-null    object
#  9   TossDecision     118 non-null    object
#  10  SuperOver        117 non-null    object
#  11  WinningTeam      118 non-null    object
#  12  WonBy            118 non-null    object
#  13  Margin           116 non-null    float64
#  14  method           3 non-null      object
#  15  Player_of_Match  118 non-null    object
# ...

# %%
cricket['ID'] = cricket['ID'].astype('int32')

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               118 non-null    int32
#  1   City             118 non-null    object
#  2   Date             118 non-null    object
#  3   Season           118 non-null    object
#  4   MatchNumber      118 non-null    object
#  5   Team1            118 non-null    object
#  6   Team2            118 non-null    object
#  7   Venue            118 non-null    object
#  8   TossWinner       118 non-null    object
#  9   TossDecision     118 non-null    object
#  10  SuperOver        117 non-null    object
#  11  WinningTeam      118 non-null    object
#  12  WonBy            118 non-null    object
#  13  Margin           116 non-null    float64
#  14  method           3 non-null      object
#  15  Player_of_Match  118 non-null    object
# ...

# %%
# Convert 'toss_decision' and 'super_over' columns into category data type
cricket['TossDecision'] = cricket['TossDecision'].astype('category')
cricket['SuperOver'] = cricket['SuperOver'] .astype('category')

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               118 non-null    int32
#  1   City             118 non-null    object
#  2   Date             118 non-null    object
#  3   Season           118 non-null    object
#  4   MatchNumber      118 non-null    object
#  5   Team1            118 non-null    object
#  6   Team2            118 non-null    object
#  7   Venue            118 non-null    object
#  8   TossWinner       118 non-null    object
#  9   TossDecision     118 non-null    category
#  10  SuperOver        117 non-null    category
#  11  WinningTeam      118 non-null    object
#  12  WonBy            118 non-null    object
#  13  Margin           116 non-null    float64
#  14  method           3 non-null      object
#  15  Player_of_Match  118 non-null    object
# ...

# %%
cricket['City'].value_counts()
# Out:
# City
# Mumbai        15
# Sydney        15
# Adelaide      15
# Manchester    13
# Dhaka         12
# Kolkata       11
# London        11
# Ahmedabad     10
# Melbourne      8
# Lahore         8
# Name: count, dtype: int64

# %%
# how many matches each team has played
pd.concat([cricket['Team1'], cricket['Team2']]).value_counts()
# Out:
# Pakistan        28
# New Zealand     27
# India           27
# Bangladesh      24
# Sri Lanka       24
# South Africa    23
# Afghanistan     22
# West Indies     22
# Australia       20
# England         19
# Name: count, dtype: int64

# %%
# sort_values -> ascending -> na_position -> inplace -> multiple cols
students.sort_values(by=['iq', 'percent'], ascending=[True, False], na_position='first', inplace=True)
students
# Out:
#          iq  percent  lpa
# name
# Zaman     0        0    0
# Karim     0        0    0
# Rahman   80       50    2
# Labib    90       70    7
# Sony    100       80   10
# Hasan   120      100   14
